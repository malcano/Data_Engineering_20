# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import wordcloud

# %%
tech_venture_info = pd.read_csv('data/기술보증기금_벤처기업정보_20210228.csv', encoding='cp949')
service_industry_index = pd.read_csv('data/산업별_서비스업생산지수.csv',index_col='업종별',encoding='cp949')
industry_job = pd.read_csv('data/산업별_취업자_20230201103717.csv', encoding='cp949')
customer_movement = pd.read_csv('data/소비자동향조사_전국_1월.csv',index_col='CSI분류코드별', encoding='cp949')
city_industry_type_worker = pd.read_csv('data/시도_산업_사업체구분별_종사자.csv',index_col = '행정구역별', encoding='cp949')
city_industry_company_number = pd.read_csv('data/시도_산업별_사업체수.csv', encoding='cp949')
all_industry = pd.read_csv('data/전산업생산지수_1월.csv',encoding='cp949')

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts()

font_list = fm.findSystemFonts(fontpaths=None)
font_list
mpl.rcParams['font.family']
plt.style.use("default")

path = '/Users/minholee/Library/Fonts/NanumSquareR.ttf'

font_name = fm.FontProperties(fname=path, size=50).get_name()
print(font_name)
plt.rc('font', family=font_name)

mpl.rcParams["axes.unicode_minus"] = False
# Out:
# NanumSquare

# %%
tech_venture_info = tech_venture_info
tech_venture_info.columns
# Out:
# Index(['구분년월', '제조업', '정보처리', '연구개발서비스', '건설운수', '도소매업', '농_어_임_광업', '기타'], dtype='object')

# %%
January_tech_venture_info = tech_venture_info['구분년월'].str.contains("-01")
January_tech_venture_info = tech_venture_info[January_tech_venture_info]
January_tech_venture_info #1월 데이터만 추출
# Out:
#        구분년월    제조업  정보처리  연구개발서비스  건설운수  도소매업  농_어_임_광업    기타
# 0   2013-01  20767  4317      306   400   349        74  2229
# 12  2014-01  21016  4722      330   420   360        62  2449
# 24  2015-01  21384  4927      320   431   408        48  2535
# 36  2016-01  22047  5203      330   464   545        56  2714
# 48  2017-01  23403  5492      380   518   690        78  2826
# 60  2018-01  24595  5838      454   598   838        86  3103
# 72  2019-01  25116  6290      553   640   934        94  3429
# 84  2020-01  24742  6640      655   678   870       102  3473
# 96  2021-01  25686  7332      848   788   977       107  3853

# %%
January_tech_venture_info_remove_index = January_tech_venture_info.set_index("구분년월")

# %%
#sns.displot(data = January_tech_venture_info ,x= January_tech_venture_info["구분년월"].value_counts(), kind="kde")
#
# January_tech_venture_info_remove_index = January_tech_venture_info_remove_index.transpose()
# January_tech_venture_info_remove_index = January_tech_venture_info_remove_index.drop("지울예정", axis =1 )

# %%
plt.figure(figsize=(12,12))
plt.plot(January_tech_venture_info_remove_index)
# sns.displot(data=January_tech_venture_info_remove_index, x = "제조업", kind = 'kde')
# sns.displot(data=January_tech_venture_info_remove_index, x = "정보처리", kind = 'kde')
plt.title("testcase plot graph")
plt.show()
#sub plot

# %%
January_tech_venture_info_remove_index = January_tech_venture_info_remove_index.transpose()

# %%
jan_tech_bef_df = January_tech_venture_info_remove_index
jan_tech_aft_df = January_tech_venture_info_remove_index

# %%
jan_tech_bef_df
# Out:
# 구분년월      지울예정  2013-01  2014-01  2015-01  2016-01  2017-01  2018-01  2019-01  \
# 제조업          0    20767    21016    21384    22047    23403    24595    25116
# 정보처리         0     4317     4722     4927     5203     5492     5838     6290
# 연구개발서비스      0      306      330      320      330      380      454      553
# 건설운수         0      400      420      431      464      518      598      640
# 도소매업         0      349      360      408      545      690      838      934
# 농_어_임_광업     0       74       62       48       56       78       86       94
# 기타           0     2229     2449     2535     2714     2826     3103     3429
#
# 구분년월      2020-01  2021-01
# 제조업         24742    25686
# 정보처리         6640     7332
# 연구개발서비스       655      848
# 건설운수          678      788
# 도소매업          870      977
# 농_어_임_광업      102      107
# 기타           3473     3853

# %%
jan_tech_aft_df = jan_tech_aft_df.drop(columns='지울예정')

# %%
# jan_tech_aft_df.insert(len(jan_tech_aft_df.values), '지울예정', [0 for x in range(len(jan_tech_aft_df.index))])

# %%
# jan_tech_bef_df.insert(0, '지울예정', [0 for x in range(len(jan_tech_bef_df.index))])
#copy_df.drop('지울예정',axis=1)
# Out:
# 구분년월      지울예정  2013-01  2014-01  2015-01  2016-01  2017-01  2018-01  2019-01  \
# 제조업          0    20767    21016    21384    22047    23403    24595    25116
# 정보처리         0     4317     4722     4927     5203     5492     5838     6290
# 연구개발서비스      0      306      330      320      330      380      454      553
# 건설운수         0      400      420      431      464      518      598      640
# 도소매업         0      349      360      408      545      690      838      934
# 농_어_임_광업     0       74       62       48       56       78       86       94
# 기타           0     2229     2449     2535     2714     2826     3103     3429
#
# 구분년월      2020-01  2021-01
# 제조업         24742    25686
# 정보처리         6640     7332
# 연구개발서비스       655      848
# 건설운수          678      788
# 도소매업          870      977
# 농_어_임_광업      102      107
# 기타           3473     3853

# %%
jan_tech_aft_df['지울예정'] = [0 for x in range(len(jan_tech_aft_df.index))]

# %%
jan_tech_aft_df
# Out:
# 구분년월      2013-01  2014-01  2015-01  2016-01  2017-01  2018-01  2019-01  \
# 제조업         20767    21016    21384    22047    23403    24595    25116
# 정보처리         4317     4722     4927     5203     5492     5838     6290
# 연구개발서비스       306      330      320      330      380      454      553
# 건설운수          400      420      431      464      518      598      640
# 도소매업          349      360      408      545      690      838      934
# 농_어_임_광업       74       62       48       56       78       86       94
# 기타           2229     2449     2535     2714     2826     3103     3429
#
# 구분년월      2020-01  2021-01  지울예정
# 제조업         24742    25686     0
# 정보처리         6640     7332     0
# 연구개발서비스       655      848     0
# 건설운수          678      788     0
# 도소매업          870      977     0
# 농_어_임_광업      102      107     0
# 기타           3473     3853     0

# %%
jan_tech_aft_df['2013-01'].dtype
# Out:
# dtype('int64')

# %%
display(jan_tech_aft_df,jan_tech_bef_df)
# Out:
# 구분년월      2013-01  2014-01  2015-01  2016-01  2017-01  2018-01  2019-01  \
# 제조업         20767    21016    21384    22047    23403    24595    25116
# 정보처리         4317     4722     4927     5203     5492     5838     6290
# 연구개발서비스       306      330      320      330      380      454      553
# 건설운수          400      420      431      464      518      598      640
# 도소매업          349      360      408      545      690      838      934
# 농_어_임_광업       74       62       48       56       78       86       94
# 기타           2229     2449     2535     2714     2826     3103     3429
#
# 구분년월      2020-01  2021-01  지울예정
# 제조업         24742    25686     0
# 정보처리         6640     7332     0
# 연구개발서비스       655      848     0
# 건설운수          678      788     0
# 도소매업          870      977     0
# 농_어_임_광업      102      107     0
# 기타           3473     3853     0
# 구분년월      지울예정  2013-01  2014-01  2015-01  2016-01  2017-01  2018-01  2019-01  \
# 제조업          0    20767    21016    21384    22047    23403    24595    25116
# 정보처리         0     4317     4722     4927     5203     5492     5838     6290
# 연구개발서비스      0      306      330      320      330      380      454      553
# 건설운수         0      400      420      431      464      518      598      640
# 도소매업         0      349      360      408      545      690      838      934
# 농_어_임_광업     0       74       62       48       56       78       86       94
# 기타           0     2229     2449     2535     2714     2826     3103     3429
#
# 구분년월      2020-01  2021-01
# 제조업         24742    25686
# 정보처리         6640     7332
# 연구개발서비스       655      848
# 건설운수          678      788
# 도소매업          870      977
# 농_어_임_광업      102      107
# 기타           3473     3853

# %%
jan_tech_aft_df.columns
# Out:
# Index(['2021-01', '2013-01', '2014-01', '2015-01', '2016-01', '2017-01',
#        '2018-01', '2019-01', '2020-01', '2021-01'],
#       dtype='object', name='구분년월')

# %%
jan_tech_aft_df = jan_tech_aft_df.rename(columns ={'2013-01': "지울예정2"})

# %%
for i in range(1,len(jan_tech_aft_df.columns)):
    jan_tech_aft_df.rename(columns ={jan_tech_aft_df.columns[i]:jan_tech_bef_df.columns[i]}, inplace= True)

# %%
display(jan_tech_aft_df,jan_tech_bef_df)
# Out:
# 구분년월      지울예정2  2013-01  2014-01  2015-01  2016-01  2017-01  2018-01  \
# 제조업       20767    21016    21384    22047    23403    24595    25116
# 정보처리       4317     4722     4927     5203     5492     5838     6290
# 연구개발서비스     306      330      320      330      380      454      553
# 건설운수        400      420      431      464      518      598      640
# 도소매업        349      360      408      545      690      838      934
# 농_어_임_광업     74       62       48       56       78       86       94
# 기타         2229     2449     2535     2714     2826     3103     3429
#
# 구분년월      2019-01  2020-01  2021-01
# 제조업         24742    25686        0
# 정보처리         6640     7332        0
# 연구개발서비스       655      848        0
# 건설운수          678      788        0
# 도소매업          870      977        0
# 농_어_임_광업      102      107        0
# 기타           3473     3853        0
# 구분년월      지울예정  2013-01  2014-01  2015-01  2016-01  2017-01  2018-01  2019-01  \
# 제조업          0    20767    21016    21384    22047    23403    24595    25116
# 정보처리         0     4317     4722     4927     5203     5492     5838     6290
# 연구개발서비스      0      306      330      320      330      380      454      553
# 건설운수         0      400      420      431      464      518      598      640
# 도소매업         0      349      360      408      545      690      838      934
# 농_어_임_광업     0       74       62       48       56       78       86       94
# 기타           0     2229     2449     2535     2714     2826     3103     3429
#
# 구분년월      2020-01  2021-01
# 제조업         24742    25686
# 정보처리         6640     7332
# 연구개발서비스       655      848
# 건설운수          678      788
# 도소매업          870      977
# 농_어_임_광업      102      107
# 기타           3473     3853

# %%
jan_tech_aft_df.rename(columns ={jan_tech_aft_df.columns[1]: "지울예정"})
jan_tech_aft_df
# Out:
# 구분년월      2021-01  2013-01  2014-01  2015-01  2016-01  2017-01  2018-01  \
# 제조업         20767    21016    21384    22047    23403    24595    25116
# 정보처리         4317     4722     4927     5203     5492     5838     6290
# 연구개발서비스       306      330      320      330      380      454      553
# 건설운수          400      420      431      464      518      598      640
# 도소매업          349      360      408      545      690      838      934
# 농_어_임_광업       74       62       48       56       78       86       94
# 기타           2229     2449     2535     2714     2826     3103     3429
#
# 구분년월      2019-01  2020-01  2021-01
# 제조업         24742    25686        0
# 정보처리         6640     7332        0
# 연구개발서비스       655      848        0
# 건설운수          678      788        0
# 도소매업          870      977        0
# 농_어_임_광업      102      107        0
# 기타           3473     3853        0

# %%
past_tech_p = (jan_tech_aft_df-jan_tech_bef_df)/jan_tech_aft_df*100
past_tech_p
# Out:
# 구분년월        2013-01    2014-01    2015-01    2016-01    2017-01    2018-01  \
# 제조업        1.184812   1.720913   3.007212   5.794129   4.846514   2.074375
# 정보처리       8.576874   4.160747   5.304632   5.262200   5.926687   7.186010
# 연구개발서비스    7.272727  -3.125000   3.030303  13.157895  16.299559  17.902351
# 건설운수       4.761905   2.552204   7.112069  10.424710  13.377926   6.562500
# 도소매업       3.055556  11.764706  25.137615  21.014493  17.661098  10.278373
# 농_어_임_광업 -19.354839 -29.166667  14.285714  28.205128   9.302326   8.510638
# 기타         8.983258   3.392505   6.595431   3.963199   8.926845   9.507145
#
# 구분년월        2019-01    2020-01  2021-01  지울예정  지울예정2
# 제조업       -1.511600   3.675154     -inf   NaN    NaN
# 정보처리       5.271084   9.438080     -inf   NaN    NaN
# 연구개발서비스   15.572519  22.759434     -inf   NaN    NaN
# 건설운수       5.604720  13.959391     -inf   NaN    NaN
# 도소매업      -7.356322  10.951894     -inf   NaN    NaN
# 농_어_임_광업   7.843137   4.672897     -inf   NaN    NaN
# 기타         1.266916   9.862445     -inf   NaN    NaN

# %%
get_past_tech_p = past_tech_p.iloc[:,0:8]
get_past_tech_p
# Out:
# 구분년월        2013-01    2014-01    2015-01    2016-01    2017-01    2018-01  \
# 제조업        1.184812   1.720913   3.007212   5.794129   4.846514   2.074375
# 정보처리       8.576874   4.160747   5.304632   5.262200   5.926687   7.186010
# 연구개발서비스    7.272727  -3.125000   3.030303  13.157895  16.299559  17.902351
# 건설운수       4.761905   2.552204   7.112069  10.424710  13.377926   6.562500
# 도소매업       3.055556  11.764706  25.137615  21.014493  17.661098  10.278373
# 농_어_임_광업 -19.354839 -29.166667  14.285714  28.205128   9.302326   8.510638
# 기타         8.983258   3.392505   6.595431   3.963199   8.926845   9.507145
#
# 구분년월        2019-01    2020-01
# 제조업       -1.511600   3.675154
# 정보처리       5.271084   9.438080
# 연구개발서비스   15.572519  22.759434
# 건설운수       5.604720  13.959391
# 도소매업      -7.356322  10.951894
# 농_어_임_광업   7.843137   4.672897
# 기타         1.266916   9.862445

# %%
for i in range(0,len(get_past_tech_p.columns)):
    get_past_tech_p.rename(columns ={get_past_tech_p.columns[i]:str(2014+i)}, inplace= True)
get_past_tech_p
#본 데이터는 기술보증기금_벤처기업정보_20210228을 기준으로 기업 정보 순에서 한 각 분야별 성장률을 추출한 값입니다.
# Out:
# 구분년월           2014       2015       2016       2017       2018       2019  \
# 제조업        1.184812   1.720913   3.007212   5.794129   4.846514   2.074375
# 정보처리       8.576874   4.160747   5.304632   5.262200   5.926687   7.186010
# 연구개발서비스    7.272727  -3.125000   3.030303  13.157895  16.299559  17.902351
# 건설운수       4.761905   2.552204   7.112069  10.424710  13.377926   6.562500
# 도소매업       3.055556  11.764706  25.137615  21.014493  17.661098  10.278373
# 농_어_임_광업 -19.354839 -29.166667  14.285714  28.205128   9.302326   8.510638
# 기타         8.983258   3.392505   6.595431   3.963199   8.926845   9.507145
#
# 구분년월           2020       2021
# 제조업       -1.511600   3.675154
# 정보처리       5.271084   9.438080
# 연구개발서비스   15.572519  22.759434
# 건설운수       5.604720  13.959391
# 도소매업      -7.356322  10.951894
# 농_어_임_광업   7.843137   4.672897
# 기타         1.266916   9.862445

# %%
get_past_tech_p.to_csv("get_past_tech_p.csv", sep=',', na_rep='NaN', encoding='utf-8')

# %%
json = get_past_tech_p.to_json("get_past_tech_p.json", force_ascii=False)

# %%
import pymysql
from sqlalchemy import create_engine

# %%
pymysql.install_as_MySQLdb()
import MySQLdb

# %%
connect=pymysql.connect(
    host='localhost',
    user = 'root',
    password = 'alsgh5600',
    db='qwer_db',
    charset='utf8'
)

# %%
get_past_tech_p = get_past_tech_p.transpose()

# %%
# fig = plt.figure(figsize=(12,12))
# plt.title("get_past_tech_p")
get_past_tech_p.index
#get_past_tech_p.제조업
# Out:
# Index(['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], dtype='object', name='구분년월')

# %%
lengend = get_past_tech_p.transpose().index

# %%
lengend
# Out:
# Index(['제조업', '정보처리', '연구개발서비스', '건설운수', '도소매업', '농_어_임_광업', '기타'], dtype='object')

# %%
colors = ['black', 'lightpink', 'darkgray', 'hotpink', 'rosybrown', 'deeppink','darkorange']
sns.set_palette("pastel")

plt.figure(figsize=(12,8))
plt.title("산업별 성장률")
for i in range(len(get_past_tech_p.columns)):
    sns.lineplot(get_past_tech_p[get_past_tech_p.columns[i]],markers=True, linewidth=5)
plt.legend(lengend)

# %%
print(all_industry["산업별 지수"].index)
all_industry
# Out:
# RangeIndex(start=0, stop=5, step=1)
#              산업별 지수  2013.01  2013.02  2013.03  2013.04  2013.05  2013.06  \
# 0  전산업생산지수(농림어업 제외)   95.900   97.300   95.400   96.800   96.800   96.600
# 1               광공업  100.815   99.717   98.379   99.213   99.510   99.701
# 2               건설업   88.025   92.171   91.715   97.754   96.356   97.302
# 3              서비스업   94.000   95.400   94.200   94.800   95.100   94.800
# 4              공공행정   94.700  105.200   94.100  100.600   97.400   95.000
#
#    2013.07  2013.08  2013.09  ...  2022.03  2022.04  2022.05  2022.06  \
# 0   96.400   97.200   96.600  ...    117.3    116.3    117.1    118.0
# 1   98.765  100.173   98.938  ...    121.2    117.3    117.6    119.7
# 2   97.512   96.089   97.929  ...    108.5    108.3    114.2    112.8
# 3   94.700   95.700   95.200  ...    114.2    115.6    116.7    116.5
# 4   96.500   94.900   95.200  ...    129.0    123.0    120.4    125.1
#
#    2022.07  2022.08  2022.09  2022.10  2022.11 p)  2022.12 p)
# 0    117.8    117.7    117.2    115.4       115.9       114.0
# 1    118.2    116.6    114.3    110.4       111.1       107.9
# 2    109.4    113.5    113.9    119.7       123.0       111.3
# 3    116.7    118.8    118.7    117.5       117.2       117.0
# 4    129.7    117.8    121.5    118.7       123.1       121.8
#
# [5 rows x 121 columns]

# %%
all_industry_tp = all_industry.transpose()
# all_industry_tp["index"] = [0 for x in range(len(all_industry_tp.index))]

# %%
all_industry_cp = all_industry

# %%
all_industry_cp.set_index("산업별 지수")
# Out:
#                   2013.01  2013.02  2013.03  2013.04  2013.05  2013.06  \
# 산업별 지수
# 전산업생산지수(농림어업 제외)   95.900   97.300   95.400   96.800   96.800   96.600
# 광공업               100.815   99.717   98.379   99.213   99.510   99.701
# 건설업                88.025   92.171   91.715   97.754   96.356   97.302
# 서비스업               94.000   95.400   94.200   94.800   95.100   94.800
# 공공행정               94.700  105.200   94.100  100.600   97.400   95.000
#
#                   2013.07  2013.08  2013.09  2013.10  ...  2022.03  2022.04  \
# 산업별 지수                                                ...
# 전산업생산지수(농림어업 제외)   96.400   97.200   96.600   97.800  ...    117.3    116.3
# 광공업                98.765  100.173   98.938  100.843  ...    121.2    117.3
# 건설업                97.512   96.089   97.929   99.367  ...    108.5    108.3
# 서비스업               94.700   95.700   95.200   95.600  ...    114.2    115.6
# 공공행정               96.500   94.900   95.200   98.500  ...    129.0    123.0
#
#                   2022.05  2022.06  2022.07  2022.08  2022.09  2022.10  \
# 산업별 지수
# 전산업생산지수(농림어업 제외)    117.1    118.0    117.8    117.7    117.2    115.4
# 광공업                 117.6    119.7    118.2    116.6    114.3    110.4
# 건설업                 114.2    112.8    109.4    113.5    113.9    119.7
# 서비스업                116.7    116.5    116.7    118.8    118.7    117.5
# 공공행정                120.4    125.1    129.7    117.8    121.5    118.7
#
#                   2022.11 p)  2022.12 p)
# 산업별 지수
# 전산업생산지수(농림어업 제외)       115.9       114.0
# 광공업                    111.1       107.9
# 건설업                    123.0       111.3
# 서비스업                   117.2       117.0
# 공공행정                   123.1       121.8
#
# [5 rows x 120 columns]

# %%
all_industry_cp=all_industry_cp.transpose()

# %%
all_industry_cp.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
all_industry_tp.reset_index(drop=False, inplace=True)
all_industry_tp
# Out:
#           index                 0        1       2      3      4
# 0        산업별 지수  전산업생산지수(농림어업 제외)      광공업     건설업   서비스업   공공행정
# 1       2013.01              95.9  100.815  88.025   94.0   94.7
# 2       2013.02              97.3   99.717  92.171   95.4  105.2
# 3       2013.03              95.4   98.379  91.715   94.2   94.1
# 4       2013.04              96.8   99.213  97.754   94.8  100.6
# ..          ...               ...      ...     ...    ...    ...
# 116     2022.08             117.7    116.6   113.5  118.8  117.8
# 117     2022.09             117.2    114.3   113.9  118.7  121.5
# 118     2022.10             115.4    110.4   119.7  117.5  118.7
# 119  2022.11 p)             115.9    111.1   123.0  117.2  123.1
# 120  2022.12 p)             114.0    107.9   111.3  117.0  121.8
#
# [121 rows x 6 columns]

# %%
Jan_all_industry = all_industry_tp['index'].str.contains("\.01")
Jan_all_industry
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 116    False
# 117    False
# 118    False
# 119    False
# 120    False
# Name: index, Length: 121, dtype: bool

# %%
Jan_all_industry = all_industry_tp[Jan_all_industry]
Jan_all_industry #1월 데이터만 추출
# Out:
#        index      0        1        2      3      4
# 1    2013.01   95.9  100.815   88.025   94.0   94.7
# 13   2014.01   98.7  101.318  100.518   97.1   97.4
# 25   2015.01   97.8     97.7     97.2   97.9   97.4
# 37   2016.01  100.2     99.0    104.7  100.5   99.5
# 49   2017.01  105.0    106.3    122.0  103.2  100.2
# 61   2018.01  107.0    105.2    135.3  105.7  102.9
# 73   2019.01  108.2    105.4    126.1  108.3  106.5
# 85   2020.01  110.6    108.3    123.4  110.4  112.6
# 97   2021.01  109.5    111.8    108.3  106.9  119.1
# 109  2022.01  115.7    119.4    115.3  112.8  120.5

# %%
all_industry_list = all_industry["산업별 지수"].values

# %%
all_industry_list
# Out:
# array(['전산업생산지수(농림어업 제외)', '광공업', '건설업', '서비스업', '공공행정'], dtype=object)

# %%
for i in range(0,len(all_industry_list)):
    Jan_all_industry.rename(columns ={Jan_all_industry.columns[i+1]:all_industry_list[i]}, inplace= True)
Jan_all_industry
# Out:
# /var/folders/s0/5rhprztj2xs1kzwd87bwg_y00000gn/T/ipykernel_2375/3253178730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jan_all_industry.rename(columns ={Jan_all_industry.columns[i+1]:all_industry_list[i]}, inplace= True)
# /var/folders/s0/5rhprztj2xs1kzwd87bwg_y00000gn/T/ipykernel_2375/3253178730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jan_all_industry.rename(columns ={Jan_all_industry.columns[i+1]:all_industry_list[i]}, inplace= True)
# /var/folders/s0/5rhprztj2xs1kzwd87bwg_y00000gn/T/ipykernel_2375/3253178730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jan_all_industry.rename(columns ={Jan_all_industry.columns[i+1]:all_industry_list[i]}, inplace= True)
# /var/folders/s0/5rhprztj2xs1kzwd87bwg_y00000gn/T/ipykernel_2375/3253178730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jan_all_industry.rename(columns ={Jan_all_industry.columns[i+1]:all_industry_list[i]}, inplace= True)
# /var/folders/s0/5rhprztj2xs1kzwd87bwg_y00000gn/T/ipykernel_2375/3253178730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jan_all_industry.rename(columns ={Jan_all_industry.columns[i+1]:all_industry_list[i]}, inplace= True)
#        index 전산업생산지수(농림어업 제외)      광공업      건설업   서비스업   공공행정
# 1    2013.01             95.9  100.815   88.025   94.0   94.7
# 13   2014.01             98.7  101.318  100.518   97.1   97.4
# 25   2015.01             97.8     97.7     97.2   97.9   97.4
# 37   2016.01            100.2     99.0    104.7  100.5   99.5
# 49   2017.01            105.0    106.3    122.0  103.2  100.2
# 61   2018.01            107.0    105.2    135.3  105.7  102.9
# 73   2019.01            108.2    105.4    126.1  108.3  106.5
# 85   2020.01            110.6    108.3    123.4  110.4  112.6
# 97   2021.01            109.5    111.8    108.3  106.9  119.1
# 109  2022.01            115.7    119.4    115.3  112.8  120.5

# %%
Jan_all_industry.to_csv("all_industry.csv", encoding="utf-8")

# %%
Jan_all_industry = Jan_all_industry.set_index('index')
Jan_all_industry
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[558], line 1
# ----> 1 Jan_all_industry = Jan_all_industry.set_index('index')
#       2 Jan_all_industry
#
# File ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pandas/core/frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
#    6011 if inplace:
#    6012     frame = self
#
# KeyError: "None of ['index'] are in the columns"

# %%
Jan_all_industry = Jan_all_industry.transpose()

# %%
Jan_all_industry= Jan_all_industry.transpose()

# %%
Jan_all_industry
# Out:
# index             2013.01  2014.01 2015.01 2016.01 2017.01 2018.01 2019.01  \
# 전산업생산지수(농림어업 제외)     95.9     98.7    97.8   100.2   105.0   107.0   108.2
# 광공업               100.815  101.318    97.7    99.0   106.3   105.2   105.4
# 건설업                88.025  100.518    97.2   104.7   122.0   135.3   126.1
# 서비스업                 94.0     97.1    97.9   100.5   103.2   105.7   108.3
# 공공행정                 94.7     97.4    97.4    99.5   100.2   102.9   106.5
#
# index            2020.01 2021.01 2022.01
# 전산업생산지수(농림어업 제외)   110.6   109.5   115.7
# 광공업                108.3   111.8   119.4
# 건설업                123.4   108.3   115.3
# 서비스업               110.4   106.9   112.8
# 공공행정               112.6   119.1   120.5

# %%
sns.set_palette("pastel")
plt.figure(figsize=(12,8))

# 전산업생산지수(농림어업 제외)	광공업	건설업	서비스업	공공행정
# plt.title("산업생산지수")
ind_df = Jan_all_industry['2013.01']
sns.barplot(x = Jan_all_industry.index, y= ind_df)
# sns.countplot(data=survey_df , x = "Age", order = age_order)
plt.ylim(80, 140)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.set_palette("pastel")
# 전산업생산지수(농림어업 제외)	광공업	건설업	서비스업	공공행정
plt.title("산업생산지수")
plt.figure(figsize=(12,8))

ind_df = Jan_all_industry['2014.01']
sns.barplot(x = Jan_all_industry.index, y= ind_df)
# sns.countplot(data=survey_df , x = "Age", order = age_order)
plt.ylim(80, 140)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.set_palette("pastel")
# 전산업생산지수(농림어업 제외)	광공업	건설업	서비스업	공공행정
plt.title("산업생산지수")
plt.figure(figsize=(12,8))

ind_df = Jan_all_industry['2015.01']
sns.barplot(x = Jan_all_industry.index, y= ind_df)
# sns.countplot(data=survey_df , x = "Age", order = age_order)
plt.ylim(80, 140)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.set_palette("pastel")
# 전산업생산지수(농림어업 제외)	광공업	건설업	서비스업	공공행정
plt.title("산업생산지수")
plt.figure(figsize=(12,8))

ind_df = Jan_all_industry['2016.01']
sns.barplot(x = Jan_all_industry.index, y= ind_df)
# sns.countplot(data=survey_df , x = "Age", order = age_order)
plt.ylim(80, 140)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.set_palette("pastel")
# 전산업생산지수(농림어업 제외)	광공업	건설업	서비스업	공공행정
plt.title("산업생산지수")
plt.figure(figsize=(12,8))

ind_df = Jan_all_industry['2017.01']
sns.barplot(x = Jan_all_industry.index, y= ind_df)
# sns.countplot(data=survey_df , x = "Age", order = age_order)
plt.ylim(80, 140)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.set_palette("pastel")
# 전산업생산지수(농림어업 제외)	광공업	건설업	서비스업	공공행정
plt.title("산업생산지수")
plt.figure(figsize=(12,8))

ind_df = Jan_all_industry['2018.01']
sns.barplot(x = Jan_all_industry.index, y= ind_df)
# sns.countplot(data=survey_df , x = "Age", order = age_order)
plt.ylim(80, 140)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.set_palette("pastel")
# 전산업생산지수(농림어업 제외)	광공업	건설업	서비스업	공공행정
plt.title("산업생산지수")
plt.figure(figsize=(12,8))

ind_df = Jan_all_industry['2019.01']
sns.barplot(x = Jan_all_industry.index, y= ind_df)
# sns.countplot(data=survey_df , x = "Age", order = age_order)
plt.ylim(80, 140)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.set_palette("pastel")
# 전산업생산지수(농림어업 제외)	광공업	건설업	서비스업	공공행정
plt.title("산업생산지수")
plt.figure(figsize=(12,8))

ind_df = Jan_all_industry['2020.01']
sns.barplot(x = Jan_all_industry.index, y= ind_df)
# sns.countplot(data=survey_df , x = "Age", order = age_order)
plt.ylim(80, 140)
plt.xticks(rotation = 90)
plt.show()

# %%
tech_venture_info = pd.read_csv('data/기술보증기금_벤처기업정보_20210228.csv', encoding='cp949')
service_industry_index = pd.read_csv('data/산업별_서비스업생산지수.csv',index_col='업종별',encoding='cp949')
tech_venture_info.to_csv("tmp_1bef.csv", encoding='utf-8-sig')
service_industry_index.to_csv("tmp_2bef.csv", encoding='utf-8-sig')

# %%
tmp1 = pd.read_csv('data/tmp_1aft.csv', encoding='cp949')
tmp2 = pd.read_csv('data/tmp_2aft.csv', encoding='cp949')

# %%
tmp1.to_csv("tmp_1aft.csv", encoding='utf-8-sig')
tmp2.to_csv("tmp_2aft.csv", encoding='utf-8-sig')
